# %% [markdown]
# # Diferenciación numerica

# %% [markdown]
# ## Hacia adelante

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### Error
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Hacia atras
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Diferencia centrada o  fórmula del punto medio de tres puntos
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Inestabilidad del error de redondeo
#
# Para reducir el error de truncamiento, necesitamos reducir h. Pero conforme h se reduce, el error de redondeo $\frac{ε}{h}$ crece. En la práctica, entonces, casi nunca es ventajoso dejar
# que h sea demasiado pequeña, porque en este caso, el error de redondeo dominará los cálculos.
# Un minimo para h esta dado por:
#
#
# ![image.png](attachment:image.png)
#
# para las x que pertencen al intervalo [minimo(x),max(x)]

# %% [markdown]
# ## Integracion Numerica

# %% [markdown]
# ### Teorema del valor medio para la integral
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Formula de Integracion Numerica
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Regla del trapecio

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Regla compuesta de trapecio
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Regla de Simpson

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Regla compuesta de Simpson
#
# ![image.png](attachment:image.png)

# %%
# import numpy as np
# def funx_s(x):
#     return x*np.log(x)
    
# def simpson1(a,b,n):
#     h = (b-a)/n
#     XI_0 = funx_s(a) + funx_s(b)
#     XI_1 = 0 # suma de f(x_2i-1)
#     XI_2 = 0 # suma de f(x_2i)
#     i = 1
#     k = n/2
#     while i < k-1:
#         x = a + h*(2*i)
#         print(h)
#         XI_2 = XI_2 + funx_s(x)
#         i = i+1
#     j = 1
#     while j < k:
#         x = a + h*(2*i-1)
#         print(a)
#         XI_1 = XI_1 + funx_s(x)
#         i = i+1
#     XI = h*(XI_0+(2*XI_2)+(4*XI_1))/3
#     return XI

# %%
print(simpson1(0,1,6))
# Out:
# 0.16666666666666666
# 0
# 0
# nan
# C:\Users\steven\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\steven\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in double_scalars
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
def funx_s(x):
    return 7 + 14*(x**6)
    
def simpson(a,b,n):
    h = (b-a)/n
    XI_0 = funx_s(a) + funx_s(b)
    XI_1 = 0 # suma de f(x_2i-1)
    XI_2 = 0 # suma de f(x_2i)
    i = 1
    while i <= n-1:
        X = a + i*h
        if i%2 == 0:
            XI_2 = XI_2 + funx_s(X)
        else:
            XI_1 = XI_1 + funx_s(X)
        i = i+1
    XI = h*(XI_0+(2*XI_2)+(4*XI_1))/3
    return XI

# %%
print(simpson(0,1,6))
# Out:
# 9.007058756287151
